# %% [markdown]
# # Confidence Intervals

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\sunta\\OneDrive\\Desktop\\data\\sampling\\car\\audi.csv')

# %%
df.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %% [markdown]
# *If, Population standard deviation is know and it is assumed to be σ = 11,850*
#
# *What will be the confidence interval*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.random.seed(11)
sample_500 = df['price'].sample(500)
sample_mean = np.round((np.mean(sample_500)),2)
print('Printing sample 500 mean', sample_mean)
# Out:
# Printing sample 500 mean 22194.15

# %%
# Use formula and calculate the range

error = 11850/np.sqrt(500)

# %%
np.round(sample_mean - 1.96*error,2)
# Out:
# 21155.45

# %%
np.round(sample_mean + 1.96*error,2)
# Out:
# 23232.85

# %% [markdown]
# *So at 95% confidence the value of the population mean falls within the range is [21155.45, 23232.85]*

# %% [markdown]
# *If you do not have population standard deviation. You can use t-distribution instead of Z*

# %% [markdown]
# to calculate 95% confidence interval, with only 15 samples?

# %%
np.random.seed(11)
sample_size = 15
sample_15 = df['mileage'].sample(sample_size)
sample_mean = np.round(np.mean(sample_15),2)
sample_sd = np.round(np.std(sample_15),2)

# %%
dfreedom = sample_size - 1 # degrees of freedom

# %%
# t-distribution, will give t- value
from scipy import stats
stats.t.ppf(1-0.025,dfreedom)
# Out:
# 2.1447866879169273

# %% [markdown]
# *Insert all these values in the formula*

# %%
std_error = sample_sd/np.sqrt(sample_size)

# %%
sample_mean+stats.t.ppf(1-0.025,dfreedom)*std_error
# Out:
# 22657.680723726065

# %%
sample_mean-stats.t.ppf(1-0.025,dfreedom)*std_error
# Out:
# 6227.259276273933

# %% [markdown]
# Range is [6227.25, 22657.68]

# %% [markdown]
# *Note: the confidence is very high*

# %% [markdown]
# Read more -https://www.kaggle.com/code/gireeshs/learn-statistics-2-confidence-interval/notebook~

# %% [markdown]
# Learn more - https://www.youtube.com/watch?v=BQ88ni4bJNA
#
#
# https://www.youtube.com/watch?v=9GtaIHFuEZU
